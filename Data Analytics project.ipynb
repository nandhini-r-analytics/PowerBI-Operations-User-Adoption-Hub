# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/sales_data (2).csv', encoding='ISO-8859-1')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#FETCHING NULL DATA FROM AMOUNT COLOUMN
#df.info()
amount_null=df[df['Amount'].isnull()]['Cust_name']
amount_null
# Out:
# 7      Shivangi
# 14         Cano
# 16          Amy
# 109      Sakshi
# 111     Apoorva
# 184      Kartik
# 293    Jonathan
# 344     Lakshmi
# 345     Srishti
# 452      Gaurav
# 464      Anurag
# 493      Hemant
# Name: Cust_name, dtype: object

# %%
#DROPING UNWANTED COLUMNS SUCH AS STATUS,UNNAMED 1
df.drop(['Status','unnamed1'],axis=1,inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#DELETE ALL NAN VALUES FROM THE DATA FRAME
#df.dropna(axis=0,inplace =True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
#Rename the column Marital_Status to Marital
new={'Marital_Status':'Marital'}
df.rename(columns=new,inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
#change the values of Marital col 0-->single, 1--> married
df['Marital']=df['Marital'].map({0:'single',1:'married'})
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28   single
# 1      1000732       Kartik  P00110942      F     26-35   35  married
# 2      1001990        Bindu  P00118542      F     26-35   35  married
# 3      1001425       Sudevi  P00237842      M      0-17   16   single
# 4      1000588         Joni  P00057942      M     26-35   28  married
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19  married
# 11247  1004089  Reichenbach  P00171342      M     26-35   33   single
# 11248  1001209        Oshin  P00201342      F     36-45   40   single
# 11249  1004023       Noonan  P00059442      M     36-45   37   single
# 11250  1002744      Brumley  P00281742      F     18-25   19   single
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
#change the values of Gender col F-->Female, M-->Male
df['Gender']=df['Gender'].map({'F':'Female','M':'Male'})
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital  \
# 0      1002903    Sanskriti  P00125942  Female     26-35   28   single
# 1      1000732       Kartik  P00110942  Female     26-35   35  married
# 2      1001990        Bindu  P00118542  Female     26-35   35  married
# 3      1001425       Sudevi  P00237842    Male      0-17   16   single
# 4      1000588         Joni  P00057942    Male     26-35   28  married
# ...        ...          ...        ...     ...       ...  ...      ...
# 11246  1000695      Manning  P00296942    Male     18-25   19  married
# 11247  1004089  Reichenbach  P00171342    Male     26-35   33   single
# 11248  1001209        Oshin  P00201342  Female     36-45   40   single
# 11249  1004023       Noonan  P00059442    Male     36-45   37   single
# 11250  1002744      Brumley  P00281742  Female     18-25   19   single
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
#visualize the count of males and females based on gender column using seaborn
sb=sns.countplot(data=df,x='Gender',palette={'Female':'lightgreen','Male':'darkblue'})
for i in sb.containers:
  sb.bar_label(i)
# Out:
# /tmp/ipython-input-3980164798.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb=sns.countplot(data=df,x='Gender',palette={'Female':'lightgreen','Male':'darkblue'})

# %%
#group by gender, age_group,state,Occupation,Product_category,marital_status

a=df.groupby('Gender')['Amount'].sum()
new=pd.DataFrame(a)
new

ds=sns.barplot(data=new,x='Gender',y='Amount')
ds.set_facecolor('orange')
for i in ds.containers:
  ds.bar_label(i,fmt='%.1f')

# %%
#WHICH STATE SPENDING MORE AMOUNT
b=df.groupby('State')['Amount'].sum()
m=pd.DataFrame(b)
m
# Out:
#                        Amount
# State
# Andhra Pradesh     8037146.99
# Bihar              4022757.00
# Delhi             11603819.45
# Gujarat            3946082.00
# Haryana            4220175.00
# Himachal Pradesh   4963368.00
# Jharkhand          3026456.00
# Karnataka         13523540.00
# Kerala             3894491.99
# Madhya Pradesh     8101142.00
# Maharashtra       14427543.00
# Punjab             1525800.00
# Rajasthan          1909409.00
# Telangana          1151490.00
# Uttar Pradesh     19374968.00
# Uttarakhand        2520944.00

# %%
plt.figure(figsize=(15,8))
s=sns.barplot(data=m,x='State',y='Amount',width=0.5,palette='rainbow')
for i in s.containers:
  s.bar_label(i,fmt='%.1f')
# Out:
# /tmp/ipython-input-2957462480.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   s=sns.barplot(data=m,x='State',y='Amount',width=0.5,palette='rainbow')
